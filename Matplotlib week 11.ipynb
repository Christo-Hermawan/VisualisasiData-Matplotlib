# %% [markdown]
# ![logo%20matplotlib.jpg](attachment:logo%20matplotlib.jpg)

# %% [markdown]
# <h1> Animasi pada Matplotlib

# %%
#Import Modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.21.2

# %% [markdown]
# <h3> Review Figure

# %%
fig = plt.figure()
plt.xlim((0,4))
plt.ylim((-2,2))

print(plt.plot([]))
# Out:
# [<matplotlib.lines.Line2D object at 0x000001AF7052B370>]

# %% [markdown]
# <h3> Animasi pada Matplotlib

# %%
fig = plt.figure()
plt.xlim((0,4))
plt.ylim((-2,2))

line = plt.plot([])[0]

def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x,y)
    return line,

anim = FuncAnimation(fig, animate, frames=200, interval=10)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)

plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
